# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rc
# red, blue, green, yellow, purple, orange, teal blue, pink, other color
palette=['#ff3b30', '#4cd964','#ffcc00',  '#007aff','#5856d6', '#ff9500', '#5ac8fa', '#ff2d55','#969783']
markers=['o', '^', '<', 'd', '*','2']
sns.set_style("ticks")
import matplotlib as mpl
mpl.rcParams['lines.markersize'] = 6
mpl.rcParams['lines.linewidth']=1
rc("font", **{'family':'serif','serif':['Palatino'], 'size':12})
rc('text', usetex=True)
import os

# %%
basepath="/home/jiangnan/PycharmProjects/scibench/plots"

# %%
def plot_quantile_nmse(total, name, title, metric_name, use_logy=False, show_ylabel=True, use_hatches=False):
    GP=[abs(float(line.split("\t")[0])) for line in total.split("\n")]
    CVGP=[abs(float(line.split("\t")[1])) for line in total.split("\n")]
    VPG=[abs(float(line.split("\t")[2])) for line in total.split("\n")]
    PQT=[abs(float(line.split("\t")[3])) for line in total.split("\n")]
    DSR=[abs(float(line.split("\t")[4])) for line in total.split("\n")]
    GPMELD=[abs(float(line.split("\t")[5])) for line in total.split("\n")]
    # Eureqa=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
    MCTS=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
    CVMCTS=[abs(float(line.split("\t")[7])) for line in total.split("\n")]
    df=pd.DataFrame({
        "model": CVGP+GP+CVMCTS+MCTS+VPG+PQT+DSR+GPMELD,
        "type": ['CvGP(ours)']*10+['GP']*10+['CvMCTS(ours)']*10+['MCTS']*10+['VPG']*10+['PQT']*10+['DSR']*10+['GPMeld']*10
    })
    

    plt.figure(figsize=(3,3))
    ax=sns.boxplot(data=df, x="model", y="type", 
                   showfliers=True, 
                   width=0.5,hue='type',
                    palette=palette)
    ax.set_title(title, fontsize=16)
    ax.set(xlabel=metric_name, ylabel="")
    if use_logy==True:
        plt.xscale('log', base=10)
        
    if show_ylabel==False:
        ax.set(yticklabels=[])
    if use_hatches==True:
        hatches = ["/", "o", "*", "\\"]
        for hatch, patch in zip(hatches, ax.artists):
            patch.set_hatch(hatch)
    plt.yticks(rotation=40)    

    fname = os.path.join(basepath, name+".noisy.pdf")
    plt.savefig(fname, bbox_inches='tight', pad_inches=0)

# %% [markdown]
# # INV

# %%
total="""-0.01815020655	-0.01034790559	-7.590959832	-0.9728152653	-1.16663156	-1.077515165	-0.2799487977	-0.0001070212466
-0.1172942128	-0.09806407786	-1.324706201	-1.743211505	-4.857325015	-2.257053723	-0.6615464372	-0.01741282144
-0.611390194	-0.514784204	-1.106372825	-1.134734255	-1.158970987	-0.966477178	-0.5016996965	-0.0452490198
-0.2983387166	-0.1045129379	-0.8780049403	-1.554702308	-1.061221237	-0.9987642959	-0.1717743297	-0.0008014716511
-0.07987417653	-0.03959135489	-0.922469459	-0.9750734321	-3.727182739	-0.9710798986	-0.1768352325	-0.007737895437
-0.01395698645	-0.008544317068	-1.001713718	-1.015460303	-1.090498269	-1.038977934	-0.2057283281	-0.7924451157
title="sin, cos (4, 4, 6)"
plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=True)
# Out:
# /tmp/ipykernel_57803/4049741331.py:18: UserWarning: The palette list has more values (9) than needed (8), which may not be intended.
#   ax=sns.boxplot(data=df, x="model", y="type",

# %%
total="""-0.1434407683	-0.2255039515	-0.9916557383	-0.7106129352	-1.216170378	-5.409814901
-0.06980027956	-0.07819674222	-1.493398712	-1.565149774	-1.118437606	-6.165270776
-0.3694116012	-0.2312307852	-0.4475402662	-0.6315704167	-0.8604050772	-0.2714508752
-0.008080341266	-0.01202818029	-27.37579654	-523832.6952	-280.1496037	-177.789493
-0.8142117987	-0.4942552504	-0.5296384352	-0.5000089618	-0.4815932624	-0.9308926556
-0.06305567174	-0.04783246967	-0.3259719382	-0.3210447182	-0.4185744477	-0.3100389774
-0.08306232584	-0.05200540099	-24277.1179	-178.1812702	-96.79640031	-692.0415922
-0.09834181698	-0.05515144408	-39.01121516	-496.351251	-347.815984	-50.71454329
-0.0518945667	-0.9960665023	-48.58419256	-246.644653	-10197.63789	-2400.400395
-0.8023605093	-0.03404872992	-141212828	-72.02875696	-63.69277524	-502.909802"""
metric_name="NMSE"
name="sincos_nv5_nt55_"+metric_name
title="sin, cos (5, 5, 5)"
plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[64], line 14
#      12 name="sincos_nv5_nt55_"+metric_name
#      13 title="sin, cos (5, 5, 5)"
# ---> 14 plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=True)
#
# Cell In[53], line 9, in plot_quantile_nmse(total, name, title, metric_name, use_logy, show_ylabel, use_hatches)
#       7 GPMELD=[abs(float(line.split("\t")[5])) for line in total.split("\n")]
#       8 # Eureqa=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
# ----> 9 MCTS=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
#      10 CVMCTS=[abs(float(line.split("\t")[7])) for line in total.split("\n")]
#      11 df=pd.DataFrame({
#      12     "model": CVGP+GP+CVMCTS+MCTS+VPG+PQT+DSR+GPMELD,
# ...

# %%
total="""-0.1330889109	-0.1168963549	-297.5353109	-2781.112396	-61.32173708	-214.1689235
-0.05012528661	-0.0773733807	-70.5415026	-4301.900516	-632.1262258	-45.03236815
-0.006226095091	-0.008101991359	-221.0284366	-173.641793	-36638.02789	-3550.043192
-0.0216589596	-0.1090459628	-191.092243	-577.8292344	-215.3073797	-93.35771238
-0.4284705563	-0.268172969	-740.0329289	-53.09971777	-175.1364785	-11140.20114
-0.105889394	-0.2194723925	-25890.8999	-413.3868437	-82.82231887	-660.6659199
-0.9268873561	-0.05257465688	-36.16676777	-486.2716871	-17863.82106	-513.4132247
-0.2657584194	-0.2706824319	-0.6550864345	-0.5401474928	-0.4298658278	-0.6020001069
-0.7207321543	-0.1711009326	-982.1856751	-529.2722584	-98.29548328	-94.19372292
-0.09223236266	-0.05728489716	-63.95898725	-181.2170548	-252.9523428	-668.539433"""
metric_name="NMSE"
name="sincos_nv5_nt58_"+metric_name
title="sin, cos (5, 5, 8)"
plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[65], line 14
#      12 name="sincos_nv5_nt58_"+metric_name
#      13 title="sin, cos (5, 5, 8)"
# ---> 14 plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=True)
#
# Cell In[53], line 9, in plot_quantile_nmse(total, name, title, metric_name, use_logy, show_ylabel, use_hatches)
#       7 GPMELD=[abs(float(line.split("\t")[5])) for line in total.split("\n")]
#       8 # Eureqa=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
# ----> 9 MCTS=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
#      10 CVMCTS=[abs(float(line.split("\t")[7])) for line in total.split("\n")]
#      11 df=pd.DataFrame({
#      12     "model": CVGP+GP+CVMCTS+MCTS+VPG+PQT+DSR+GPMELD,
# ...

# %%
total="""-0.1859934116	-0.1240407386	-8.189798968	-11.20709479	-52.14207698	-1.183118385
-0.1078815838	-0.1141020323	-0.9837648455	-0.9170073396	-1.073360873	-1.071547402
-0.05683416755	-0.1250126764	-1.920679846	-1.673426371	-4.44646179	-4.451741761
-1.010795866	-0.5092085268	-1.147969462	-1.421562242	-1.956590555	-1.018767893
-0.9711285535	-1.000713726	-1.612204164	-1.543214913	-1.67070538	-1.541085
-0.1780949166	-0.1457839965	-54.89578358	-27.65956066	-73.64494488	-6.876848026
-0.6588422316	-0.3958526079	-7.844056796	-8.101464789	-0.8219723225	-0.6621724218
-0.1859718225	-0.03229115151	-2.471575795	-19.01754162	-1.164114271	-13.46456035
-0.7503731015	-0.5204517647	-4.673486966	-0.5681716783	-1.356784298	-1.414085513
-0.1695992762	-0.1934176122	-2.320129638	-16.59558204	-1.833082097	-12.95821806"""
metric_name="NMSE"
name="sincos_nv6_nt68_"+metric_name
title="sin, cos (6, 6, 8)"
plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[66], line 14
#      12 name="sincos_nv6_nt68_"+metric_name
#      13 title="sin, cos (6, 6, 8)"
# ---> 14 plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=True)
#
# Cell In[53], line 9, in plot_quantile_nmse(total, name, title, metric_name, use_logy, show_ylabel, use_hatches)
#       7 GPMELD=[abs(float(line.split("\t")[5])) for line in total.split("\n")]
#       8 # Eureqa=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
# ----> 9 MCTS=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
#      10 CVMCTS=[abs(float(line.split("\t")[7])) for line in total.split("\n")]
#      11 df=pd.DataFrame({
#      12     "model": CVGP+GP+CVMCTS+MCTS+VPG+PQT+DSR+GPMELD,
# ...

# %%
total="""-0.3219801786	-0.1677804875	-36.70721405	-2.737230967	-13.79276776	-13.84883828
-0.1196550307	-0.2548207413	-1.746417864	-1.970366265	-1.740463714	-0.771319089
-0.3273102533	-0.1350058444	-133.3019193	-48450.73132	-120.5481695	-271.9153362
-0.347245228	-0.2374862568	-1.345005215	-2.996303215	-2.627132434	-1.450638592
-0.9975033101	-0.3460474235	-18.57031176	-15.81718413	-19.55016309	-26.18320363
-0.2495544204	-0.0718920724	-1.013866851	-0.8043051429	-1.038510961	-59.79504203
-0.3523931381	-0.3491586007	-6.513300488	-55.75231194	-56.69029604	-5.820478667
-0.172364708	-0.1324952191	-3.160789243	-3.371088733	-3.219078661	-3.765322187
-0.301239017	-0.06526172753	-27.35068922	-26.78309092	-29.40415462	-29.19125874
-0.2074222267	-0.1534030626	-8.283438734	-7.963588047	-9.562359612	-9.176462509"""
metric_name="NMSE"
name="sincos_nv6_nt610_"+metric_name
title="sin, cos (6, 6, 10)"
plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[67], line 14
#      12 name="sincos_nv6_nt610_"+metric_name
#      13 title="sin, cos (6, 6, 10)"
# ---> 14 plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=True)
#
# Cell In[53], line 9, in plot_quantile_nmse(total, name, title, metric_name, use_logy, show_ylabel, use_hatches)
#       7 GPMELD=[abs(float(line.split("\t")[5])) for line in total.split("\n")]
#       8 # Eureqa=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
# ----> 9 MCTS=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
#      10 CVMCTS=[abs(float(line.split("\t")[7])) for line in total.split("\n")]
#      11 df=pd.DataFrame({
#      12     "model": CVGP+GP+CVMCTS+MCTS+VPG+PQT+DSR+GPMELD,
# ...

# %% [markdown]
# # SIN COS INV

# %%
total="""-1.017175943	-0.2274168885	-1.845977278	-1.009967918	-0.9954248041	-1.166464164
-0.05282470711	-0.03185680208	-1.061918993	-1.489592425	-1.195014969	-2.036108545
-0.2006301277	-0.1228329459	-0.9999665503	-1.003359191	-1.004630438	-1.042019379
-0.3110207381	-0.3335382038	-0.9684294707	-1.307615674	-0.8909431423	-1.023999469
-0.02801609371	-0.01448465194	-15.01578101	-1.016037521	-1.68830378	-1.01550932
-0.7786124429	-0.8026912542	-1.010395458	-1.384552095	-1.053990369	-1.090887173
-0.8053820681	-0.1967930309	-1.040194975	-1.286491887	-1.041733196	-1.092122065
-0.006767190081	-0.009535078742	-1.845729946	-1.008558904	-1.015136423	-1.093908396
-0.01260312325	-0.002959727471	-1.557451427	-2.00142708	-1.032122227	-2.420647205
-0.2756257683	-0.1597597235	-1.012549872	-10.46493508	-1.02922904	-1.969727321"""
metric_name="NMSE"
name="sincosinv_nv4_nt46_"+metric_name
title="sin, cos, inv (4, 4, 6)"
plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 14
#      12 name="sincosinv_nv4_nt46_"+metric_name
#      13 title="sin, cos, inv (4, 4, 6)"
# ---> 14 plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=True)
#
# Cell In[53], line 9, in plot_quantile_nmse(total, name, title, metric_name, use_logy, show_ylabel, use_hatches)
#       7 GPMELD=[abs(float(line.split("\t")[5])) for line in total.split("\n")]
#       8 # Eureqa=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
# ----> 9 MCTS=[abs(float(line.split("\t")[6])) for line in total.split("\n")]
#      10 CVMCTS=[abs(float(line.split("\t")[7])) for line in total.split("\n")]
#      11 df=pd.DataFrame({
#      12     "model": CVGP+GP+CVMCTS+MCTS+VPG+PQT+DSR+GPMELD,
# ...

# %%
total="""-0.0222315649	-0.319247736	-1.345935446	-1.014537559	-1.152038754	-1.004848269	-0.6344468994	-0.002144911873
-0.1625884658	-0.02001444641	-1.009769726	-0.9996291848	-1.096776719	-1.010315192	-0.7746062244	-0.4548485527
-0.04682476643	-0.03803389612	-1.04228528	-1.048326337	-1.100172499	-1.002180075	-0.5683027001	-0.0002880926993
-0.5780599884	-0.4780158944	-1.014485874	-1.013422346	-1.001497857	-1.041582114	-0.9019272689	-0.2279895686
-0.2279308926	-0.1838410521	-70.70777357	-2.84380057	-6.677962625	-4.474802034	-0.3907855006	-1.268261528
-0.226600492	-0.6840561984	-0.98016335	-1.000993592	-18.30958833	-1.043786533	-0.5337658245	-0.03542099068
-0.3727988681	-1.000610065	-40.2558068	-3.860917103	-65.19532409	-8.885876408	-0.7875953398	-0.06098096306
-0.5345349711	-0.1303742768	-0.9995324401	-1.021562775	-1.016293858	-0.9991150922	-0.8438556378	-0.4673272871
-0.01981164062	-0.01691463069	-1.003454683	-2.397779616	-1.03157304	-1.029461775	-0.1152903726	-0.02756953838
-0.02484776305	-0.005741392147	-1.005378409	-1.006549765	-1.01187197	-6.323510927	-0.3476886694	-0.0007585116117"""
metric_name="NMSE"
name="sincosinv_nv5_nt55_"+metric_name
title="sin, cos, inv (5, 5, 5)"
plot_quantile_nmse(total, name, title,metric_name=metric_name, use_logy=True, show_ylabel=False)
# Out:
# /tmp/ipykernel_57803/4049741331.py:18: UserWarning: The palette list has more values (9) than needed (8), which may not be intended.
#   ax=sns.boxplot(data=df, x="model", y="type",

# %%
total="""-0.0129879102	-0.02764243496	-1.002220341	-0.9875870186	-1.00682853	-2.952065554	-0.6962780442	-0.1765418193
-0.09168916353	-0.06639416839	-1.006715701	-1.01080162	-1.000085547	-1.011568053	-0.397186599	-0.06306725393
-0.1756320479	-0.1287788982	-1.007454355	-1.013281104	-1.004485298	-1.013784785	-0.4315359961	-0.07451231788
-0.1707501043	-0.2023111441	-26.77592327	-105.2233075	-18.96431608	-269.9188696	-0.1884884369	-0.02248692665
